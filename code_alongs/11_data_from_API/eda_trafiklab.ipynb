# %% [markdown]
# # EDA on trafiklab resrobot API

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()

API_KEY = os.getenv("API_KEY")

url = f"https://api.resrobot.se/v2.1/trip?format=json&originId=740000001&destId=740000003&passlist=true&showPassingPoints=true&accessId={API_KEY}"

respone = requests.get(url)

respone.text
# Out:
# '{"Trip":[{"Origin":{"name":"Stockholm Centralstation","type":"ST","id":"A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@","extId":"740000001","lon":18.058151,"lat":59.330136,"routeIdx":0,"prognosisType":"PROGNOSED","time":"11:24:00","date":"2025-01-07","minimumChangeDuration":"PT20M"},"Destination":{"name":"Malmö Centralstation","type":"ST","id":"A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@","extId":"740000003","lon":13.00091,"lat":55.609456,"routeIdx":8,"prognosisType":"PROGNOSED","time":"15:52:00","date":"2025-01-07","minimumChangeDuration":"PT15M"},"ServiceDays":[{"planningPeriodBegin":"2024-12-11","planningPeriodEnd":"2025-06-15","sDaysR":"inte varje dag","sDaysI":"7. jan t o m 9. jun 2025; utom 8., 9. feb, 1., 2., 15. mar, 7. t o m 11. apr 2025, 14. apr, 21. t o m 28. apr 2025, 1. t o m 9. maj 2025, 17. t o m 23. maj 2025, 6. t o m 8. jun 2025","sDaysB":"00000FFFFFFFFFE7FFFF3FFDFFFFF837E01803F80FFF8800"}],"LegList":{"Leg":[{"Origin":{"name":"Stockholm Centralstation","type":"ST","id":"A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@","extId":"740000001","lon":18.058151,"lat":59.330136,"routeIdx":0,"prognosisType":"PROGNOSED","time":"11:24:00","date":"2025-01-07","minimumChangeDuration":"PT20M"},"Destination":{"name":"Malmö Centralstation","type":"ST","id":"A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@","extId":"740000003","lon":13.00091,"lat":55.609456,"routeIdx":8,"prognosisType":"PROGNOSED","time":"15:52:00","date":"2025-01-07","minimumChangeDuration":"PT15M"},"Notes":{"Note":[{"value":"X2000","key":"VX","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"X2000"},{"value":"Mat 1 klass","key":"A1","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"Mat 1 klass"},{"value":"Bistrovagn","key":"AD","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"Bistrovagn"},{"value":"Obligatorisk platsbokning","key":"AF","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"Obligatorisk platsbokning"},{"value":"Rullstolslyft","key":"AN","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"Rullstolslyft"},{"value":"WiFi","key":"AW","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"WiFi"},{"value":"2 klass lugn","key":"BL","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"2 klass lugn"},{"value":"EU förordning 2021/782","key":"EJ","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"EU förordning 2021/782"},{"value":"Maträtt","key":"SM","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"Maträtt"},{"value":"1 klass med extra komfort","key":"SU","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"1 klass med extra komfort"},{"value":"Kaffebuffé 1 klass","key":"SZ","type":"A","routeIdxFrom":0,"routeIdxTo":8,"txtN":"Kaffebuffé 1 klass"}]},"JourneyDetailRef":{"ref":"1|78475|0|1|7012025"},"JourneyStatus":"P","Product":[{"icon":{"res":"prod_gen"},"operatorInfo":{"name":"SJ","nameS":"74","nameN":"74","nameL":"SJ","id":"74"},"name":"Snabbtåg 531","internalName":"Snabbtåg 531","displayNumber":"531","num":"531","line":"531","lineId":"1074053100001","catOut":"JST","catIn":"JST","catCode":"1","cls":"2","catOutS":"JST","catOutL":"Snabbtåg","operatorCode":"74","operator":"SJ","admin":"074___","routeIdxFrom":0,"routeIdxTo":8,"matchId":"531;531;45017"}],"Stops":{"Stop":[{"name":"Stockholm Centralstation","id":"A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@","extId":"740000001","routeIdx":0,"lon":18.058151,"lat":59.330136,"depPrognosisType":"PROGNOSED","depTime":"11:24:00","depDate":"2025-01-07","depDir":"Malmö Centralstation","minimumChangeDuration":"PT20M"},{"Notes":{"Note":[{"value":"Stannar endast för påstigande","key":"text.realtime.stop.exit.disabled","type":"R","txtN":"Stannar endast för påstigande"}]},"name":"Södertälje Syd station","id":"A=1@O=Södertälje Syd station@X=17645367@Y=59162415@U=1@L=740000055@","extId":"740000055","routeIdx":1,"lon":17.645367,"lat":59.162415,"depTime":"11:43:00","depDate":"2025-01-07","alighting":false,"minimumChangeDuratio ...
